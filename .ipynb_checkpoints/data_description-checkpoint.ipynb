# %% [markdown]
# # Data description
# Ich möchte eine Vorhersage zum "price actual", also die Kosten für Strom in Euro pro MegaWattstunde treffen.
# Untersuchte Stadt ist Valencia, Spanien.
#
# Informationen zur Kolumnen:
# "timestamp" zeigt Datum und Uhrzeit.
# "temperature" ist die Temperatur in Kelvin.
# "humidity" ist die Luftfeuchtigkeit in %.
# "wind_speed" ist die Windgeschwiendigkeit in m/s.
# "clouds_coverage" beschreibt in wie viel prozent ist der Himmel mit Wolken bedeckt.
# "weather clear/cloudy/rain" ist die kategorische Beschreibung der Wetter.
# "generation solar" und "wind onshore" sind die Stromerzeugung in MW angezeigt.
# "total load actual" ist die tatsächliche Nachfrage nach Strom. In der Quelle wird es nicht erklärt, ich nehme an es ist auch in MW gemeint.
# "price actual" ist die Europreis für Megawatt pro Stunde.

# %%
import pandas
import os
import matplotlib.pyplot as plt

valencia_data = pandas.read_csv(os.path.join("weather_energy_join_1.csv"))
valencia_data.drop(["city_name"], axis=1, inplace=True)
valencia_data.head(5)
# Out:
#           timestamp  temperature  humidity  wind_speed  clouds_coverage  \
# 0  01/01/2015 00:00      270.475        77           1                0
# 1  01/01/2015 01:00      270.475        77           1                0
# 2  01/01/2015 02:00      269.686        78           0                0
# 3  01/01/2015 03:00      269.686        78           0                0
# 4  01/01/2015 04:00      269.686        78           0                0
#
#    weather_clear  weather_cloudy  weather_rain  generation_solar  \
# 0              1               0             0                49
# 1              1               0             0                50
# 2              1               0             0                50
# 3              1               0             0                50
# 4              1               0             0                42
#
#    generation_wind_onshore  total_energy_demand  price
# 0                     6378                25385  65.41
# ...

# %% [markdown]
# # Statistische Informationen
# Mit eine Zeile kann die wichtigsten statistischen Daten zur diese Datensatz herausfinden.

# %%
valencia_data.describe().map('{:,.2f}'.format)
# Out:
#       temperature   humidity wind_speed clouds_coverage weather_clear  \
# count   35,060.00  35,060.00  35,060.00       35,060.00     35,060.00
# mean       290.78      65.09       2.69           20.74          0.44
# std          7.23      19.68       2.58           25.60          0.50
# min        268.83       8.00       0.00            0.00          0.00
# 25%        285.15      51.00       1.00            0.00          0.00
# 50%        290.19      67.00       2.00           20.00          0.00
# 75%        296.15      82.00       4.00           20.00          1.00
# max        311.15     100.00     133.00          100.00          1.00
#
#       weather_cloudy weather_rain generation_solar generation_wind_onshore  \
# count      35,060.00    35,060.00        35,060.00               35,060.00
# mean            0.49         0.05         1,432.09                5,461.70
# std             0.50         0.22         1,680.03                3,215.32
# ...

# %% [markdown]
# # Grafik
# Was ich denke eine Nebenerfindung bei diesen Daten zu erfinden ist, ist die Entwicklung des Preis im Laufe der Zeit. Dazu wähle ich ein einfaches Liniendiagramm. Da aber sehr viele Daten vorhanden sind, ist es alles ganz nah zu sich und gibt einen guten Überblick über die Entwicklung.

# %%
df = pandas.DataFrame(valencia_data)

df['timestamp'] = pandas.to_datetime(df['timestamp'], format='%d/%m/%Y %H:%M')

plt.figure(figsize=(10, 6))
plt.plot(df['timestamp'], df['price'], marker='o', color='blue')

plt.title("Entwicklung der Strompreises", fontsize=14)
plt.xlabel("Zeit", fontsize=12)
plt.ylabel("Strompreis in Euro ", fontsize=12)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Skalierung
# Ich bin der Meinung, dass 5 fünf Kolumne ausser "preis" skaliert werden müssen. Da Preis nicht benutzt wird, um Maschine zu üben sondern ist das Beispielwert, der sich aus mehreren Variblen ausgibt.

# %%
df = pandas.DataFrame(valencia_data)

columns_to_scale = ['temperature','generation_solar', 'generation_wind_onshore', 'total_energy_demand']

for column in columns_to_scale:
    column_min = df[column].min()
    column_max = df[column].max()
    df[column] = (df[column] - column_min) / (column_max - column_min) 

print(df)
# Out:
#               timestamp  temperature  humidity  wind_speed  clouds_coverage  \
# 0      01/01/2015 00:00     0.038856        77           1                0
# 1      01/01/2015 01:00     0.038856        77           1                0
# 2      01/01/2015 02:00     0.020212        78           0                0
# 3      01/01/2015 03:00     0.020212        78           0                0
# 4      01/01/2015 04:00     0.020212        78           0                0
# ...                 ...          ...       ...         ...              ...
# 35055  31/12/2018 19:00     0.397202        62           2                0
# 35056  31/12/2018 20:00     0.338128        71           1                0
# 35057  31/12/2018 21:00     0.303156        81           3                0
# 35058  31/12/2018 22:00     0.267238        81           2                0
# 35059  31/12/2018 23:00     0.243608        75           2                0
#
# ...
